# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.tradutoradeespanhol.com.br/2013/10/as-expressoes-si-mesmo-e-si-proprio-sao.html#:~:text=O%20emprego%20de%20uma%20express%C3%A3o,exige%20muito%20de%20si%20pr%C3%B3prio%E2%80%9D.'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html.parser')
texto = soup.get_text()

print(texto)
# Out:
# Tradutora de Espanhol: As expressões "si mesmo" e "si próprio" são redundantes?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Tradutora de Espanhol
#
#
#
#
# Tradução de espanhol. Diana Margarita. Blog sobre tradução, tradução de espanhol, gramática, literatura, cultura e entretenimento.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Páginas
#
#
#
# Início
#
#
# A autora
#
#
# Contato
#
#
# Currículo
#
#
# Minhas leituras
#
#
# Traduções publicadas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# quinta-feira, 31 de outubro de 2013
#
#
#
#
#
#
#
# As expressões "si mesmo" e "si próprio" são redundantes?
#
#
#
#
#
#
# O pronome "si" é pessoal do caso oblíquo refere-se à terceira pessoa do singular: "Vive cheio de si" ou à terceira pessoa do plural "Caíram em si ao receber a notícia".
#
# ...
